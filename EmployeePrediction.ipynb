# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
csv_data=pd.read_csv("emp.csv")

df=pd.DataFrame({
  'hours':csv_data["Hours"],
  'money':csv_data["incentives"]
})
x=df["Hours"]
y=df[""]
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=42)

print("training data length :",len(X_train))
print("Testing Data Length :",len(X_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       1 csv_data=pd.read_csv("emp.csv")
#       3 df=pd.DataFrame({
#       4   'hours':csv_data["Hours"],
#       5   'money':csv_data["incentives"]
#       6 })
# ----> 8 X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=42)
#      10 print("training data length :",len(X_train))
#      11 print("Testing Data Length :",len(X_test))
#
# NameError: name 'x' is not defined

# %%
model=LinearRegression()
model.fit(X_train,Y_train)

y_pred=model.predict(X_test)

print("\n Predict Money",y_pred)

print("\n Actual Money",Y_test)

# %%
model.predict([[34]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model.predict([[34]])
#
# NameError: name 'model' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AggleomerativeClustering
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 4
#       2 import matplotlib.pyplot as plt
#       3 import scipy.cluster.hierarchy as sch
# ----> 4 from sklearn.cluster import AggleomerativeClustering
#
# ImportError: cannot import name 'AggleomerativeClustering' from 'sklearn.cluster' (C:\Users\vadne\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\cluster\__init__.py)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
data=pd.read_csv("customer_segmentation_dataset.csv")
print("DataSet Preview :")
print(data.head())
# Out:
# DataSet Preview :
#    CustomerID  Age  Annual_Income  Spending_Score
# 0           1   19          15000              39
# 1           2   21          15000              81
# 2           3   20          16000               6
# 3           4   23          16000              77
# 4           5   31          17000              40

# %%
x=data[['Annual_Income','Spending_Score']]
kmeans=KMeans(n_clusters=5,random_state=42)
kmeans.fit(x)
# Out:
# KMeans(n_clusters=5, random_state=42)

# %%
data['Cluster']=kmeans.predict(x)

# %%
print("\n Clustered Data :")
print(data.head(50))
# Out:
#  Clustered Data :
#     CustomerID  Age  Annual_Income  Spending_Score  cluster  Cluster
# 0            1   19          15000              39        2        2
# 1            2   21          15000              81        2        2
# 2            3   20          16000               6        2        2
# 3            4   23          16000              77        2        2
# 4            5   31          17000              40        2        2
# 5            6   22          17000              76        2        2
# 6            7   35          18000               6        2        2
# 7            8   23          18000              94        2        2
# 8            9   64          19000               3        4        4
# 9           10   30          19000              72        4        4
# 10          11   67          20000              14        4        4
# 11          12   35          20000              99        4        4
# 12          13   58          21000              15        4        4
# 13          14   24          21000              73        4        4
# 14          15   37          22000              14        4        4
# 15          16   22          22000              79        4        4
# 16          17   35          23000              35        4        4
# 17          18   20          23000              66        4        4
# 18          19   52          24000              29        0        0
# 19          20   35          24000              98        0        0
# 20          21   35          25000              35        0        0
# 21          22   25          25000              73        0        0
# 22          23   46          26000               5        0        0
# 23          24   31          26000              73        0        0
# 24          25   54          27000              14        0        0
# 25          26   29          27000              82        0        0
# 26          27   45          28000              32        0        0
# 27          28   35          28000              61        0        0
# 28          29   40          29000              31        3        3
# 29          30   23          29000              87        3        3
# 30          31   60          30000               4        3        3
# 31          32   21          30000              73        3        3
# 32          33   53          33000               4        3        3
# 33          34   18          33000              92        3        3
# 34          35   49          33000              14        3        3
# 35          36   21          33000              81        3        3
# 36          37   42          34000              17        3        3
# 37          38   30          34000              73        3        3
# 38          39   36          37000              26        1        1
# 39          40   20          37000              75        1        1
# 40          41   65          38000              35        1        1
# 41          42   24          38000              92        1        1
# 42          43   48          39000              36        1        1
# 43          44   31          39000              61        1        1
# 44          45   49          40000              28        1        1
# 45          46   24          40000              65        1        1
# 46          47   50          42000              55        1        1
# 47          48   27          42000              47        1        1
# 48          49   29          43000              41        1        1
# 49          50   31          43000              60        1        1

# %%
plt.figure(figsize=(8,6))
plt.scatter(data['Annual_Income'],data['Spending_Score'],c=data['Cluster'],cmap='rainbow')
plt.xlabel("Annual Income($)")
plt.ylabel("Spending Score")
plt.title("Customer segmentaion using K-Means Clustering")
plt.show()

# %%
plt.figure(figsize=(8,6))

plt.scatter(data[data['Cluster']==0]['Annual_Income'],
            data[data['Cluster']==0]['Spending_Score'],
           marker='o',label='Cluster 0')
plt.scatter(data[data['Cluster']==1]['Annual_Income'],
            data[data['Cluster']==1]['Spending_Score'],
           marker='s',label="Cluster 1")
plt.scatter(data[data['Cluster']==2]['Annual_Income'],
           data[data['Cluster']==2]['Spending_Score'],
            marker='^',label="Cluster 2")
plt.scatter(data[data['Cluster']==3]['Annual_Income'],
           data[data['Cluster']==3]['Spending_Score'],
           marker="D",label="Cluster 3")
plt.scatter(data[data['Cluster']==4]['Annual_Income'],
           data[data['Cluster']==4]['Spending_Score'],
            marker="*",label="Cluster 4")

plt.xlabel("Annual_Income")
plt.ylabel("Spending Score")
plt.title("Customer Segmentation using K_Means Clustering")
plt.legend()
plt.show()

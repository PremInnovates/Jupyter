# %%
from matplotlib import pyplot as plt
import seaborn as sns
df1=sns.load_dataset('car_crashes')
plt.scatter('speeding','alcohol',data=df1)
sns.set_style("darkgrid",{'grid.color':'1.0'})
plt.show()

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df1=sns.load_dataset('car_crashes')
plt.scatter('speeding','alcohol',data=df1)
sns.set_context("poster")
#sns.set_style("darkgrid",{'grid.color':'1.0'})
plt.show()

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df1=sns.load_dataset('car_crashes')
plt.scatter('speeding','alcohol',data=df1)
sns.set_context("notebook")
#sns.set_style("darkgrid",{'grid.color':'1.0'})
plt.show()

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df1=sns.load_dataset('car_crashes')
plt.scatter('speeding','alcohol',data=df1)
sns.set_style("dark")
sns.set_context("poster")
#sns.set_style("darkgrid",{'grid.color':'1.0'})
plt.show()

# %%
import seaborn as sns
tips =sns.load_dataset("tips")
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
from matplotlib import pyplot as plt
import seaborn as sns
tips =sns.load_dataset("tips")

plt.scatter('tip','total_bill',data=tips)
sns.set_style("darkgrid",{'grid.color':'0.8'})
plt.show()

# %%
from matplotlib import pyplot as plt
import seaborn as sns
tips =sns.load_dataset("tips")
sns.set_context("notebook")
sns.relplot(data=tips,x="total_bill",y="tip")
sns.set_style("darkgrid",{'grid.color':'0.8'})

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="time",col="day",col_wrap=4)

# %%
sns.relplot(data=tips,x="size",y="tip",kind="line")
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 sns.relplot(data=tips,x="size",y="tip",kind="line")
#
# File /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data=sns.load_dataset("tips")
print(data)
sns.pointplot(x="day",y="tip",data=data)
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# ...

# %%
sns.pointplot(x="time",y="total_bill",hue="smoker",data=data,palette="Accent")
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:253: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("dark")
tips=sns.load_dataset('tips')
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Input In [42], in <cell line: 5>()
#       3 sns.set_style("dark")
#       4 tips=sns.load_dataset('tips')
# ----> 5 sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')
#
# File /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
tips=sns.load_dataset("tips")
sns.boxplot(x="day",y="total_bill",data=tips)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:253: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
flights=sns.load_dataset("flights")
flights_pivot=flights.pivot(
    index="month",
    columns="year",
    values="passengers"
)
print(flights_pivot)

plt.figure(figsize=(12,6))
sns.heatmap(flights_pivot,cmap="YlGnBu",annot=True,fmt="d")
plt.title("Monthly Airline Passengers Heatmap")
plt.xlabel("Year")
plt.ylabel("Month")
plt.show()
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
car_crashes = sns.load_dataset("car_crashes")
print(car_crashes.head())


# car_crashes_pivot=car_crashes.pivot(
#     index="total","speeding","",
#     columns="year",
#     values="passengers"
# )
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Load the car_crashes dataset
car_crashes = sns.load_dataset("car_crashes")

# Display the first few rows to understand the data
print(car_crashes.head())

# Select relevant numerical columns for a correlation heatmap
# The 'abbrev' column is a state abbreviation and not suitable for a correlation matrix
numeric_cols = car_crashes.select_dtypes(include=[np.number]).columns
df_numeric = car_crashes[numeric_cols]

# Compute the correlation matrix
corr_matrix = df_numeric.corr()

# Create the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=.5)
plt.title("Car Crashes Correlation Heatmap")
plt.show()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df=sns.load_dataset('tips')
sns.pairplot(df,hue='day')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Input In [52], in <cell line: 4>()
#       2 import matplotlib.pyplot as plt
#       3 df=sns.load_dataset('tips')
# ----> 4 sns.pairplot(df,hue='day')
#       5 plt.show()
#
# File /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

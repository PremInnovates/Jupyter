# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
customer = pd.read_csv("customer.csv")

# %%
customer.tail(15)
# Out:
#     CustomerID   Surname  Age  Gender    Geography  Balance
# 0            1     Smith   28    Male          USA     5400
# 1            2   Johnson   35  Female           UK     8200
# 2            3  Williams   42    Male          USA     9600
# 3            4     Brown   31  Female       Canada    12000
# 4            5     Jones   38    Male    Australia     8800
# 5            6    Miller   47  Female      Germany    15000
# 6            7     Davis   40    Male          USA     9100
# 7            8    Garcia   26  Female        Spain     3000
# 8            9  Martinez   52    Male       Mexico    10000
# 9           10  Anderson   34  Female       Sweden     7600
# 10          11    Taylor   45    Male           UK     8400
# 11          12    Thomas   29  Female          USA     6700
# 12          13     Moore   33    Male       Canada     9200
# 13          14    Martin   41    Male       France     9800
# 14          15       Lee   36  Female  South Korea     8600

# %%
customer.columns
# Out:
# Index(['CustomerID', 'Surname', 'Age', 'Gender', 'Geography', 'Balance'], dtype='object')

# %%
customer.drop(columns=['Surname'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 customer.drop(columns=['Surname'],inplace=True)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)
#    5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)
#    5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
#    5595         errors=errors,
# ...

# %%
new_df =customer[['Age','Gender','Balance']]
new_df.head()
# Out:
#    Age  Gender  Balance
# 0   28    Male     5400
# 1   35  Female     8200
# 2   42    Male     9600
# 3   31  Female    12000
# 4   38    Male     8800

# %%
customer.isnull().sum()
# Out:
# CustomerID    0
# Age           0
# Gender        0
# Geography     0
# Balance       0
# dtype: int64

# %%
customer[(customer['Balance']>=8000) & (customer['Balance']<=10000)]
# Out:
#     CustomerID  Age  Gender    Geography  Balance
# 1            2   35  Female           UK     8200
# 2            3   42    Male          USA     9600
# 4            5   38    Male    Australia     8800
# 6            7   40    Male          USA     9100
# 8            9   52    Male       Mexico    10000
# 10          11   45    Male           UK     8400
# 12          13   33    Male       Canada     9200
# 13          14   41    Male       France     9800
# 14          15   36  Female  South Korea     8600

# %%
customer['Geography'].value_counts()
# Out:
# Geography
# USA            4
# UK             2
# Canada         2
# Australia      1
# Germany        1
# Spain          1
# Mexico         1
# Sweden         1
# France         1
# South Korea    1
# Name: count, dtype: int64

# %%
customer.describe()
# Out:
#        CustomerID        Age       Balance
# count   15.000000  15.000000     15.000000
# mean     8.000000  37.133333   8760.000000
# std      4.472136   7.424541   2720.241586
# min      1.000000  26.000000   3000.000000
# 25%      4.500000  32.000000   7900.000000
# 50%      8.000000  36.000000   8800.000000
# 75%     11.500000  41.500000   9700.000000
# max     15.000000  52.000000  15000.000000

# %%
[f"8 x {i} = {8*i}" for i in range(1,11)]
# Out:
# ['8 x 1 = 8',
#  '8 x 2 = 16',
#  '8 x 3 = 24',
#  '8 x 4 = 32',
#  '8 x 5 = 40',
#  '8 x 6 = 48',
#  '8 x 7 = 56',
#  '8 x 8 = 64',
#  '8 x 9 = 72',
#  '8 x 10 = 80']

# %%
plt.figure()
customer['Balance'].plot(kind='hist')
plt.title("Customer Balance Distribution")
plt.xlabel("Balance")
plt.show()

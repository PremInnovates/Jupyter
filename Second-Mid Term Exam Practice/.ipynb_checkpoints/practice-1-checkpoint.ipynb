# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
tips=pd.read_csv("tips.csv")

# %%
tips.tail()
# Out:
#    Total_Bill   Tip     Sex Smoker  Day    Time  Size
# 5        8.77  2.00    Male     No  Sat  Dinner     2
# 6       26.88  3.12    Male    Yes  Sat  Dinner     4
# 7       15.04  1.96  Female    Yes  Sat  Dinner     2
# 8       14.78  3.23  Female     No  Sat  Dinner     2
# 9       30.40  5.60    Male    Yes  Fri  Dinner     4

# %%
tips['Net_Bill']=tips['Total_Bill']+(tips['Total_Bill']*0.15)
tips.head()
# Out:
#    Total_Bill   Tip     Sex Smoker  Day    Time  Size  Net_Bill
# 0       10.34  1.66  Female     No  Sun  Dinner     2   11.8910
# 1       21.01  3.50    Male     No  Sun  Dinner     3   24.1615
# 2       23.68  3.31    Male     No  Sun  Dinner     2   27.2320
# 3       24.59  3.61    Male     No  Sun  Dinner     4   28.2785
# 4       25.29  4.71  Female    Yes  Sun  Dinner     4   29.0835

# %%
tips['Sex'].value_counts()
# Out:
# Sex
# Male      6
# Female    4
# Name: count, dtype: int64

# %%
tips[(tips['Total_Bill']>15)& (tips['Tip']<5)]
# Out:
#    Total_Bill   Tip     Sex Smoker  Day    Time  Size  Net_Bill
# 1       21.01  3.50    Male     No  Sun  Dinner     3   24.1615
# 2       23.68  3.31    Male     No  Sun  Dinner     2   27.2320
# 3       24.59  3.61    Male     No  Sun  Dinner     4   28.2785
# 4       25.29  4.71  Female    Yes  Sun  Dinner     4   29.0835
# 6       26.88  3.12    Male    Yes  Sat  Dinner     4   30.9120
# 7       15.04  1.96  Female    Yes  Sat  Dinner     2   17.2960

# %%
tips['Tip'].max(),tips['Tip'].min()
# Out:
# (np.float64(5.6), np.float64(1.66))

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Total_Bill  10 non-null     float64
#  1   Tip         10 non-null     float64
#  2   Sex         10 non-null     object
#  3   Smoker      10 non-null     object
#  4   Day         10 non-null     object
#  5   Time        10 non-null     object
#  6   Size        10 non-null     int64
#  7   Net_Bill    10 non-null     float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 772.0+ bytes

# %%
plt.figure()
tips['Sex'].value_counts().plot(kind='bar')
plt.title("male Vs Female Customer")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
tips[(tips['Sex']=='Female')& (tips['Smoker']=='Yes')]
# Out:
#    Total_Bill   Tip     Sex Smoker  Day    Time  Size  Net_Bill
# 4       25.29  4.71  Female    Yes  Sun  Dinner     4   29.0835
# 7       15.04  1.96  Female    Yes  Sat  Dinner     2   17.2960

# %%
tips[tips['Day'].isin(['Sat','Sun'])]['Total_Bill'].sum()
# Out:
# np.float64(170.38000000000002)

# %%
x=[0,1,2,0]
y=[0,2,0,0]
plt.figure()
plt.plot(x,y)
plt.title("Triangle using Line Chart")
plt.show()

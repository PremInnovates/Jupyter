# %%
import pandas as pd

# %%
db={'Student':['lokesh','Vikram','Parthiben'],
    'Admission':[2023,2022,2021]}
DataFrame=pd.DataFrame(db)
print(DataFrame)
# Out:
#      Student  Admission
# 0     lokesh       2023
# 1     Vikram       2022
# 2  Parthiben       2021

# %%
print(pd.__version__)
# Out:
# 2.3.3

# %%
a=[10,20,30,40,50]
demo=pd.Series(a)
print(demo)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
demo2=pd.Series(a,index=['p1','p2','p3','p4','p5'])
print(demo2)
# Out:
# p1    10
# p2    20
# p3    30
# p4    40
# p5    50
# dtype: int64

# %% [raw]
# print(demo2['p3'])

# %%
a=[250,450,650]
demo=pd.Series(a)
print(demo)
# Out:
# 0    250
# 1    450
# 2    650
# dtype: int64

# %%
db={'Product':['Headphone','Mobile','TV','Tablet','Speqaker'],
    'Price':[25000,45800,45620,58452,69523]}
dataframe=pd.DataFrame(db)
print(dataframe)
# Out:
#      Product  Price
# 0  Headphone  25000
# 1     Mobile  45800
# 2         TV  45620
# 3     Tablet  58452
# 4   Speqaker  69523

# %%
Stmarks=pd.read_csv('P1.csv')
print(Stmarks)
# Out:
#    SrNo            Name  TotalMarks  Obtained Me  Percentage  Grade
# 0     1      Smit Joshi         500          440         NaN    NaN
# 1     2     Tejasv Modi         500          390         NaN    NaN
# 2     3  Shreya Acharya         500          400         NaN    NaN
# 3     4           Usma          500          400         NaN    NaN
# 4     5            Diya         500          360         NaN    NaN

# %%
print(Stmarks.head)
# Out:
# <bound method NDFrame.head of    SrNo            Name  TotalMarks  Obtained Me  Percentage  Grade
# 0     1      Smit Joshi         500          440         NaN    NaN
# 1     2     Tejasv Modi         500          390         NaN    NaN
# 2     3  Shreya Acharya         500          400         NaN    NaN
# 3     4           Usma          500          400         NaN    NaN
# 4     5            Diya         500          360         NaN    NaN>

# %%
print(Stmarks.tail)
# Out:
# <bound method NDFrame.tail of    SrNo            Name  TotalMarks  Obtained Me  Percentage  Grade
# 0     1      Smit Joshi         500          440         NaN    NaN
# 1     2     Tejasv Modi         500          390         NaN    NaN
# 2     3  Shreya Acharya         500          400         NaN    NaN
# 3     4           Usma          500          400         NaN    NaN
# 4     5            Diya         500          360         NaN    NaN>

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
pd.options.display.max_rows=100
print(pd.options.display.max_rows)
# Out:
# 100

# %%
print(Stmarks.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SrNo         5 non-null      int64
#  1   Name         5 non-null      object
#  2   TotalMarks   5 non-null      int64
#  3   Obtained Me  5 non-null      int64
#  4   Percentage   0 non-null      float64
#  5   Grade        0 non-null      float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 372.0+ bytes
# None
